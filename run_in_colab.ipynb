# %% [markdown]
# # Run Universal AI Agent in Google Colab
#
# This notebook sets up the necessary environment to run the Universal AI Agent system seamlessly within Google Colab.

# %% [markdown]
# ## Step 1: Clone the Repository or Upload files
# First, we will need the project code. If your project is hosted on GitHub, uncomment the git clone line below. If you plan to upload the code directly to Colab, you can use the file upload functionality.

# %%
# Uncomment the line below to clone a github repository
# !git clone <YOUR_GITHUB_REPOSITORY_URL> 

# If you cloned a repo, change your working directory to the project folder:
# %cd <YOUR_REPOSITORY_NAME>

# Alternatively, upload the project files using the file browser on the left.

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# This command installs all required python dependencies from requirements.txt
# !pip install -r requirements.txt

# %% [markdown]
# ## Step 3: Setup Environment Variables
# Set up the `.env` file with your API keys. Replace the placeholder values with your actual keys.

# %%
# %%writefile .env
# GEMINI_API_KEY="your_gemini_key_here"
# OPENAI_API_KEY="your_openai_key_here"
# ANTHROPIC_API_KEY="your_anthropic_key_here"

# %% [markdown]
# ## Step 4: Run the Application

# %% [markdown]
# ### Option A: Run Interactive Chat

# %%
# !python main.py --chat --provider auto

# %% [markdown]
# ### Option B: Run API Server and Expose with Localtunnel
# If you want to run the FastAPI server and access it, you need to expose the port since Colab doesn't allow direct local access.

# %%
# !npm install -g localtunnel

# %%
# Run the server in the background and expose port 8000
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# !python main.py --server & npx localtunnel --port 8000
